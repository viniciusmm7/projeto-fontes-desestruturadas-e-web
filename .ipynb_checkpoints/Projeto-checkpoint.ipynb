# %% [markdown]
# # Projeto final - Análise de Textos de Fontes Desestruturadas e Web
#
# ## Vinícius Matheus Morales
# ___
# ## Objetivo:
# ###  Esse projeto tem como objetivo prever o preço de um determinado imóvel com base nos seguintes parâmetros:
# - Posição na página
# - Endereço
# - Área
# - Quantidade de quartos
# - Quantidade de banheiros
# - Quantidade de vagas de automóvel
# - Preço do condomínio
# - Preço do IPTU
# - Descrição do imóvel
# - Status do imóvel na página
# - Número da página
#
# Para isso será usado o site https://www.zapimoveis.com.br
# ___

# %% [markdown]
# ## 1. Importando as bibliotecas que serão utilizadas ao longo do projeto e verificando versões

# %%
# Bibliotecas padrões do Python para lidar com textos, arquivos, requisições http, timestamps e randomização (se necessário)
import re, os, sys, requests, time, random
from unidecode import unidecode

# Bibliotecas padrões em Data Science
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Web Scraping
import bs4
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

# Preprocessamento mais adequado dos textos
import gensim
from gensim import corpora
from gensim import models
from gensim.models import Nmf
from gensim.parsing.preprocessing import remove_stopwords, preprocess_string
import spacy
from spacy import displacy
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Machine learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, r2_score, median_absolute_error, mean_absolute_error
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\viniz\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\viniz\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(f'gensim {gensim.__version__}')
print(f'nltk {nltk.__version__}')
print(f'spacy {spacy.__version__}')
# Out:
# gensim 4.2.0
# nltk 3.7
# spacy 3.3.0

# %% [markdown]
# ___
# ### 1.1 Classe para fazer toda a extração de dados necessária

# %%
# Classe para extração dos dados
class Projeto:
    def __init__(self):
        self.posicoes = []
        self.enderecos = []
        self.areas = []
        self.quartos = []
        self.banheiros = []
        self.vagas = []
        self.precos = []
        self.conds = []
        self.iptus = []
        self.descricoes = []
        self.lista_status = []
        self.paginas = []

    def get_urls(self) -> list:
        urls = []
        uf_capital = {}
        
        url_capitais = 'https://www.todamateria.com.br/capitais-do-brasil/'
        resposta = requests.get(url_capitais)
        resposta.encoding = 'utf-8'
        
        soup = BeautifulSoup(resposta.text, 'html.parser')
        
        tabela = soup.find('tbody')
        linhas = tabela.find_all('tr')
        for linha in linhas:
            uf = linha.find_all('td')[2].text
            uf = uf.lower()
            capital = linha.find_all('td')[0].text
            capital = capital.lower()
            capital = capital.split()
            capital = '-'.join(capital)
            capital = unidecode(capital)
            uf_capital[uf] = capital
        
        for uf, capital in uf_capital.items():
            url = 'https://www.zapimoveis.com.br'
            uri = '/venda/imoveis/'
            uri += f'{uf}+{capital}/'
            url += uri
            urls.append(url)
                    
        return urls
        
    def endereco(self, produto):
        try:
            endereco = produto.find('h2', class_='simple-card__address color-dark text-regular').text
            endereco = endereco.strip('\n ')
            self.enderecos.append(endereco)
        except:
            self.enderecos.append(None)

    def area(self, produto):
        try:
            area = produto.find('li', class_='feature__item text-small js-areas').text
            area = re.find_all(r'\w+', area)[-1]
            self.areas.append(area)
        except:
            self.areas.append(None)
        
    def qtd_quartos(self, produto):
        try:
            quarto = produto.find('span', attrs={'itemprop': 'numberOfRooms'}).text
            quarto = re.find_all(r'\w+', quarto)[-1]
            self.quartos.append(quarto)
        except:
            self.quartos.append(None)
        
    def qtd_banheiros(self, produto):
        try:
            banheiro = produto.find('span', attrs={'itemprop': 'numberOfBathroomsTotal'}).text
            banheiro = re.find_all(r'\w+', banheiro)[-1]
            self.banheiros.append(banheiro)
        except:
            self.banheiros.append(None)
        
    def qtd_vagas(self, produto):
        try:
            vaga = produto.find('li', class_='feature__item text-small js-parking-spaces').text
            vaga = re.find_all(r'\w+', vaga)[-1]
            self.vagas.append(vaga)
        except:
            self.vagas.append(None)
        
    def condominio(self, produto):
        try:
            cond = produto.find('li', class_='card-price__item condominium text-regular').text
            self.conds.append(''.join(re.findall(r'\d+', cond)))
        except:
            self.conds.append(None)
        
    def iptu(self, produto):
        try:
            iptu = produto.find('li', class_='card-price__item iptu text-regular').text
            self.iptus.append(''.join(re.findall(r'\d+', iptu)))
        except:
            self.iptus.append(None)
        
    def descricao(self, produto):
        try:
            descricao = produto.find('span', class_='simple-card__text text-regular').text
            self.descricoes.append(' '.join(re.findall(r'\w+', descricao)))
        except:
            self.descricoes.append(None)
        
    def status(self, produto):
        try:
            status = produto.find('small').text
            self.lista_status.append(status)
        except:
            self.lista_status.append('Comum')
        
    def preco(self, produto):
        try:
            preco = produto.find('p', class_='simple-card__price js-price color-darker heading-regular heading-regular__bolder align-left').text
            self.precos.append(''.join(re.findall(r'\d+', preco)))
        except:
            self.precos.append(None)
        
    def everything(self, produto):
        self.endereco(produto)
        self.area(produto)
        self.qtd_quartos(produto)
        self.qtd_banheiros(produto)
        self.qtd_vagas(produto)
        self.condominio(produto)
        self.iptu(produto)
        self.descricao(produto)
        self.status(produto)
        self.preco(produto)
        
    def run(self) -> pd.DataFrame:
        urls = self.get_urls()
        
        for url in urls:
            pagina = 1
            posicao = 1
            boolean = True
            while boolean:
                
                ua = UserAgent()
                
                headers = {'user-agent': ua.random}
                
                try:
                    resposta = requests.get(url+f'?pagina={pagina}', headers=headers)
                    resposta.encoding = 'utf-8'

                    soup = BeautifulSoup(resposta.text, 'html.parser')
                    

                    lista_prod = soup.find('div', class_='listings__container')
                    produtos = lista_prod.find_all('div', class_='card-container js-listing-card')

                    for produto in produtos:
                        self.posicoes.append(posicao)
                        posicao += 1

                        self.everything(produto)

                        self.paginas.append(pagina)

                    pagina += 1
                except:
                    pagina = 1
                    boolean = False
        
        dicionario = {'Posição': self.posicoes,
                      'Endereço': self.enderecos,
                      'Área': self.areas,
                      'Quartos': self.quartos,
                      'Banheiros': self.banheiros,
                      'Vagas': self.vagas,
                      'Condomínio': self.conds,
                      'IPTU': self.iptus,
                      'Descrição': self.descricoes,
                      'Status': self.lista_status,
                      'Página': self.paginas,
                      'Preço': self.precos}
        
        df = pd.DataFrame(dicionario)
        
        return df

# %%
# Criando objeto do projeto e lendo os seus dados em formato de DataFrame
projeto = Projeto()
df = projeto.run()
df
# Out:
# url https://www.zapimoveis.com.br/venda/imoveis/ac+rio-branco/
# pag 1
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ac+rio-branco/
# pag 2
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ac+rio-branco/
# pag 3
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ac+rio-branco/
# pag 4
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ac+rio-branco/
# pag 5
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ac+rio-branco/
# pag 6
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ac+rio-branco/
# pag 7
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ac+rio-branco/
# pag 8
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 1
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 2
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 3
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 4
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 5
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 6
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 7
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 8
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 9
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 10
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 11
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 12
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 13
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 14
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 15
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 16
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 17
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 18
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 19
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 20
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 21
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 22
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 23
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 24
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 25
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 26
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 27
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 28
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 29
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 30
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 31
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 32
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 33
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 34
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 35
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 36
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 37
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 38
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 39
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 40
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 41
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 42
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 43
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 44
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 45
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 46
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 47
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 48
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 49
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 50
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 51
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 52
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 53
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 54
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 55
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 56
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 57
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 58
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/al+maceio/
# pag 59
# <Response [403]>
# url https://www.zapimoveis.com.br/venda/imoveis/ap+macapa/
# pag 1
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ap+macapa/
# pag 2
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ap+macapa/
# pag 3
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ap+macapa/
# pag 4
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ap+macapa/
# pag 5
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ap+macapa/
# pag 6
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ap+macapa/
# pag 7
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ap+macapa/
# pag 8
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ap+macapa/
# pag 9
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ap+macapa/
# pag 10
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/ap+macapa/
# pag 11
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 1
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 2
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 3
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 4
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 5
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 6
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 7
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 8
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 9
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 10
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 11
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 12
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 13
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 14
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 15
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 16
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 17
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 18
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 19
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 20
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 21
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 22
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 23
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 24
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 25
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 26
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 27
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 28
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 29
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 30
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 31
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 32
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 33
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 34
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 35
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 36
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 37
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 38
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 39
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 40
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 41
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 42
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 43
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 44
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 45
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 46
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 47
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 48
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 49
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 50
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 51
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 52
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 53
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 54
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 55
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 56
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 57
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 58
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 59
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 60
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 61
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 62
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 63
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 64
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 65
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 66
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 67
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 68
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 69
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 70
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 71
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 72
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 73
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 74
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 75
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 76
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 77
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 78
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 79
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 80
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 81
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 82
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 83
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 84
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 85
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 86
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 87
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 88
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 89
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 90
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 91
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 92
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 93
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 94
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 95
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 96
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 97
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 98
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 99
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 100
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 101
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 102
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 103
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 104
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 105
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 106
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 107
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 108
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 109
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 110
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 111
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 112
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 113
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 114
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 115
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 116
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 117
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 118
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 119
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 120
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 121
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 122
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 123
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 124
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 125
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 126
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 127
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 128
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 129
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 130
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 131
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 132
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 133
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 134
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 135
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 136
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 137
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 138
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 139
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 140
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 141
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 142
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 143
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 144
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 145
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 146
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 147
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 148
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 149
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 150
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 151
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 152
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 153
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 154
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 155
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 156
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 157
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 158
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 159
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 160
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 161
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 162
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 163
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 164
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 165
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 166
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 167
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 168
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 169
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 170
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 171
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 172
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 173
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 174
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 175
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 176
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 177
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 178
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 179
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 180
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 181
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 182
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 183
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 184
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 185
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 186
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 187
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 188
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 189
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 190
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 191
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 192
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 193
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 194
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 195
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 196
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 197
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 198
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 199
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 200
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 201
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 202
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 203
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 204
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 205
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 206
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 207
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 208
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 209
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 210
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 211
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 212
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 213
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 214
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 215
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 216
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 217
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 218
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 219
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 220
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 221
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 222
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 223
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 224
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 225
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 226
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 227
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 228
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 229
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 230
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 231
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 232
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 233
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 234
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 235
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 236
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 237
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 238
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 239
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 240
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 241
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 242
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 243
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 244
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 245
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 246
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 247
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 248
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 249
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 250
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 251
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 252
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 253
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 254
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 255
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 256
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 257
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 258
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 259
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 260
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 261
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 262
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 263
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 264
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 265
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 266
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 267
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 268
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 269
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 270
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 271
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 272
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 273
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 274
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 275
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 276
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 277
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 278
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 279
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 280
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 281
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 282
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 283
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 284
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 285
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 286
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 287
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 288
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 289
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 290
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 291
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 292
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 293
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 294
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 295
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 296
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 297
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 298
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 299
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 300
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 301
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 302
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 303
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 304
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 305
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 306
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 307
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 308
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 309
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 310
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 311
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 312
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 313
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 314
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 315
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 316
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 317
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 318
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 319
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 320
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 321
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 322
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 323
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 324
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 325
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 326
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 327
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 328
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 329
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 330
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 331
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 332
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 333
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 334
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 335
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 336
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 337
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 338
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 339
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 340
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 341
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 342
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 343
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 344
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 345
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 346
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 347
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 348
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 349
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 350
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 351
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 352
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 353
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 354
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 355
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 356
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 357
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 358
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 359
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 360
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 361
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 362
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 363
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 364
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 365
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 366
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 367
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 368
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 369
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 370
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 371
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 372
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 373
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 374
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 375
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 376
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 377
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 378
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 379
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 380
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 381
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 382
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 383
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 384
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 385
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 386
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 387
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 388
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 389
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 390
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 391
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 392
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 393
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 394
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 395
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 396
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 397
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 398
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 399
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 400
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 401
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 402
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 403
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 404
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 405
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 406
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 407
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 408
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 409
# <Response [200]>
# url https://www.zapimoveis.com.br/venda/imoveis/am+manaus/
# pag 410
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/ba+salvador/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/ce+fortaleza/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/df+brasilia/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/es+vitoria/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/go+goiania/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/ma+sao-luis/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/mt+cuiaba/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/ms+campo-grande/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/mg+belo-horizonte/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/pa+belem/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/pb+joao-pessoa/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/pr+curitiba/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/pe+recife/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/pi+teresina/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/rn+natal/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/rs+porto-alegre/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/ro+porto-velho/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/rr+boa-vista/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/sc+florianopolis/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/sp+sao-paulo/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/se+aracaju/
# pag 1
# <Response [429]>
# url https://www.zapimoveis.com.br/venda/imoveis/to+palmas/
# pag 1
# <Response [429]>
#    Posição                                       Endereço  Área Quartos  \
# 0        1                      Rua Acre, Vila da Amizade  None    None
# 1        2                     Joao Eduardo I, Rio Branco  None    None
# 2        3         Rua Independência, Conjunto Bela Vista  None    None
# 3        4                    Conjunto Tucuma, Rio Branco  None    None
# 4        5  Rua Raimundo Ferreira, Conjunto Universitario  None    None
#
#   Banheiros Vagas Condomínio  IPTU  \
# 0      None  None        200  None
# 1      None  None       None   528
# 2      None  None       None  None
# 3      None  None       None   336
# 4      None  None       None  None
#
#                                            Descrição          Status  Página  \
# 0  Vende se apartamento no Residencial Villacre c...  Super destaque       1
# 1  Em busca de uma casa que possa lhe proporciona...           Comum       1
# 2  Vende se uma casa no Conjunto Bela Vista Sala ...           Comum       1
# 3  Imóvel localizado no conjunto Tucumã Ótimo par...        Destaque       1
# 4  A casa está localizado no bairro Conjunto Univ...           Comum       1
#
#     Preço
# 0  143000
# 1  270000
# 2  320000
# 3  190000
# 4  300000

# %% [markdown]
# ___
# ### 1.2 Classificação das variáveis
# - Posição = Quantitativa
# - Área = Quantitativa
# - Quartos = Quantitativa
# - Banheiros = Quantitativa
# - Vagas = Quantitativa
# - Condomínio = Quantitativa
# - IPTU = Quantitativa
# - Página = Quantitativa
#
#
# - Endereço = Qualitativa
# - Descrição = Qualitativa
# - Status = Qualitativa
# - Range = Qualitativa (adicionada mais para frente do projeto)
#
#
# - Preço = TARGET

# %% [markdown]
# ___
# ### 1.3 Gerando nome do arquivo

# %%
# Bloco para gerar um novo arquivo de dados diferente dos demais
cwd = str(os.getcwd())
_, _, files = next(os.walk(cwd))
file_count = len(files)
print(f'Existem {file_count} arquivos no diretório do projeto')

df.to_csv(f'data{file_count - 1}.csv')
# Out:
# Existem 40 arquivos no diretório do projeto

# %% [markdown]
# ___
# ### 1.4 Criando algumas funções que podem ser úteis

# %%
# Acessar os dados salvos e criar um novo DataFrame sem os duplicados

# Acessando os nomes dos arquivos para coleta de dados
def get_data_files() -> list:
    global files
    
    data_files = []
    
    for file in files:
        if 'data' in file:
            data_files.append(file)
            
    return data_files

# Gerar um dicionário padrão do projeto
def standard_dict() -> dict:
    return {'Posição': [],
            'Endereço': [],
            'Área': [],
            'Quartos': [],
            'Banheiros': [],
            'Vagas': [],
            'Condomínio': [],
            'IPTU': [],
            'Descrição': [],
            'Status': [],
            'Página': [],
            'Preço': []}

# Gerar um novo dataframe com os dados de outras coletas excluindo duplicados
def generate_data() -> pd.DataFrame:
    dicio_vazio = standard_dict()
    memo_df = pd.DataFrame(dicio_vazio)
    data_files = get_data_files()
    
    for data in data_files:
        d = pd.read_csv(data)
        memo_df = pd.concat([memo_df, d])
        
    memo_df = memo_df.iloc[:, :-1]
    memo_df = memo_df.reset_index()
    memo_df = memo_df.drop('index', axis=1)
    memo_df = memo_df.drop_duplicates()
    
    return memo_df

# %%
# Endereçando na memória todos os dados coletados (passados + recém coletado)
memo_df = generate_data()
memo_df
# Out:
#        Posição                                           Endereço  Área  \
# 0          1.0                 Rodovia BR-364, Portal da Amazonia  420
# 1          2.0                 Rodovia BR-364, Portal da Amazonia  429
# 2          3.0  Rua Severina Maria de Sousa e Silva, Jardim Ma...   99
# 3          4.0                      Estrada do Calafate, Calafate   50
# 4          5.0                           Rua C, LBA Vila Betel ll  336
# ...        ...                                                ...   ...
# 35446     20.0                          Rua Chocalho, Castanheira  250
# 35447     21.0                        Rua Soledade, Marcos Freire   90
# 35448     22.0                 Rua Getúlio Vargas, São João Bosco  250
# 35449     23.0                              Rua Jamary, Pedrinhas  120
# 35450     24.0                             Rua Barbados, Embratel  100
#
#       Quartos Banheiros Vagas  Condomínio  IPTU  \
# 0           1         1   NaN         NaN   NaN
# 1         NaN       NaN   NaN         NaN   NaN
# 2           3         2     2       690.0   NaN
# 3           2         1     1         NaN   NaN
# 4           2         2     1         NaN   NaN
# ...       ...       ...   ...         ...   ...
# 35446       4         3     2         NaN   NaN
# 35447       2         1   NaN         NaN   NaN
# 35448       4         4     4         NaN   NaN
# 35449       3         4     2         NaN   NaN
# 35450       3         3     2       550.0   NaN
#
#                                                Descrição          Status  \
# 0      ECOVILLE- Lindo lote a venda, plano, sol da ma...  Super destaque
# 1      O lote/terreno está localizado no bairro Porta...  Super destaque
# 2      O apartamento está localizado no bairro Jardim...  Super destaque
# 3      Vendo esse imóvel em condomínio fechado. Apart...           Comum
# 4      ?Casa na Vila Betel !  Vende-se uma casa no co...           Comum
# ...                                                  ...             ...
# 35446  VENDE-SE CASA NO BAIRRO CASTANHEIRAS  Casa pos...        Destaque
# 35447  Grande oportunidade para investidor  Vila de c...           Comum
# 35448  Vendo esta excelente residencia na cidade de P...        Destaque
# 35449  A casa está localizado no bairro Pedrinhas tem...           Comum
# 35450  Vende-se apartamento  Apartamento de 100m2 com...        Destaque
#
#        Página     Preço
# 0         1.0  389000.0
# 1         1.0  360000.0
# 2         1.0  570000.0
# 3         1.0   89000.0
# 4         1.0  185000.0
# ...       ...       ...
# 35446     1.0  160000.0
# 35447     1.0  135000.0
# 35448     1.0  450000.0
# 35449     1.0  550000.0
# 35450     1.0  580000.0
#
# [20432 rows x 12 columns]

# %%
# Teste de duplicados
for i in memo_df.duplicated():
    if i:
        print("Achou duplicado")

# %% [markdown]
# ___
# ## 2. Preprocessamento de dados

# %% [markdown]
# ___
# ### 2.1 Limpeza de emojis, caracteres indesejados, stopwords e ranges salvos em dados passados

# %%
# Fazendo uma limpeza mais profunda dos dados de descrição

# Removendo emojis
memo_df = memo_df.astype(str).apply(lambda x: x.str.encode('UTF-8', 'ignore').str.decode('UTF-8'))

# Removendo caracteres indesejados como pontuação
memo_df['Descrição'] = memo_df['Descrição'].str.replace(r'[^A-z0-9À-ú]', ' ', flags=re.UNICODE)

# Removendo stopwords
memo_df['Descrição'] = memo_df['Descrição'].apply(remove_stopwords, stopwords=stopwords.words('portuguese'))

# Removendo espaços restantes nas laterais
memo_df['Descrição'] = memo_df['Descrição'].apply(lambda x: x.strip())

# Removendo "ranges" salvos de dados passados nas variáveis Área, Quartos, Banheiros, Vagas e deixando apenas o maior valor
for i in range(2,8):
    memo_df.iloc[:, i] = memo_df.iloc[:, i].apply(lambda x: int(float(x.split(' - ')[-1])) if x != 'nan' else 0)
    
# Vendo resultado
memo_df
# Out:
#       Posição                                           Endereço  Área  \
# 0         1.0                 Rodovia BR-364, Portal da Amazonia   420
# 1         2.0                 Rodovia BR-364, Portal da Amazonia   429
# 2         3.0  Rua Severina Maria de Sousa e Silva, Jardim Ma...    99
# 3         4.0                      Estrada do Calafate, Calafate    50
# 4         5.0                           Rua C, LBA Vila Betel ll   336
# ...       ...                                                ...   ...
# 35446    20.0                          Rua Chocalho, Castanheira   250
# 35447    21.0                        Rua Soledade, Marcos Freire    90
# 35448    22.0                 Rua Getúlio Vargas, São João Bosco   250
# 35449    23.0                              Rua Jamary, Pedrinhas   120
# 35450    24.0                             Rua Barbados, Embratel   100
#
#        Quartos  Banheiros  Vagas  Condomínio  IPTU  \
# 0            1          1      0           0     0
# 1            0          0      0           0     0
# 2            3          2      2         690     0
# 3            2          1      1           0     0
# 4            2          2      1           0     0
# ...        ...        ...    ...         ...   ...
# 35446        4          3      2           0     0
# 35447        2          1      0           0     0
# 35448        4          4      4           0     0
# 35449        3          4      2           0     0
# 35450        3          3      2         550     0
#
#                                                Descrição          Status  \
# 0      ECOVILLE Lindo lote venda plano sol manhã quad...  Super destaque
# 1      O lote terreno localizado bairro Portal Amazôn...  Super destaque
# 2      O apartamento localizado bairro Jardim Manoel ...  Super destaque
# 3      Vendo imóvel condomínio fechado Apartamento 2 ...           Comum
# 4      Casa Vila Betel Vende casa conj Vila Betel A c...           Comum
# ...                                                  ...             ...
# 35446  VENDE SE CASA NO BAIRRO CASTANHEIRAS Casa poss...        Destaque
# 35447  Grande oportunidade investidor Vila cinco apar...           Comum
# 35448  Vendo excelente residencia cidade Porto Velho ...        Destaque
# 35449  A casa localizado bairro Pedrinhas 120 metros ...           Comum
# 35450  Vende apartamento Apartamento 100m2 localizaçã...        Destaque
#
#       Página     Preço
# 0        1.0  389000.0
# 1        1.0  360000.0
# 2        1.0  570000.0
# 3        1.0   89000.0
# 4        1.0  185000.0
# ...      ...       ...
# 35446    1.0  160000.0
# 35447    1.0  135000.0
# 35448    1.0  450000.0
# 35449    1.0  550000.0
# 35450    1.0  580000.0
#
# [20432 rows x 12 columns]

# %% [markdown]
# ___
# ### 2.3 Conferindo quantidades de cada tipo de status e tipos de cada coluna

# %%
# Quantidade bruta de imóveis por tipo de status
memo_df['Status'].value_counts()
# Out:
# Comum                14893
# Destaque              3723
# Super destaque        1541
# Em construção          114
# Na planta               99
# Pronto para morar       62
# Name: Status, dtype: int64

# %%
# Quantidade relativa de imóveis por tipo de status
memo_df['Status'].value_counts(True).round(4)*100
# Out:
# Comum                72.89
# Destaque             18.22
# Super destaque        7.54
# Em construção         0.56
# Na planta             0.48
# Pronto para morar     0.30
# Name: Status, dtype: float64

# %%
memo_df.dtypes
# Out:
# Posição       object
# Endereço      object
# Área           int64
# Quartos        int64
# Banheiros      int64
# Vagas          int64
# Condomínio     int64
# IPTU           int64
# Descrição     object
# Status        object
# Página        object
# Preço         object
# dtype: object

# %%
# Mudando os tipos de cada variável
memo_df['Posição'] = memo_df['Posição'].astype(float).astype(int)
memo_df['Página'] = memo_df['Página'].astype(float).astype(int)
memo_df['Área'] = memo_df['Área'].astype(int)
memo_df['Quartos'] = memo_df['Quartos'].astype(int)
memo_df['Banheiros'] = memo_df['Banheiros'].astype(int)
memo_df['Vagas'] = memo_df['Vagas'].astype(int)

memo_df['Condomínio'] = memo_df['Condomínio'].astype(float).astype(int)
memo_df['IPTU'] = memo_df['IPTU'].astype(float).astype(int)
memo_df['Preço'] = memo_df['Preço'].astype(float)
memo_df.dtypes
# Out:
# Posição         int32
# Endereço       object
# Área            int32
# Quartos         int32
# Banheiros       int32
# Vagas           int32
# Condomínio      int32
# IPTU            int32
# Descrição      object
# Status         object
# Página          int32
# Preço         float64
# dtype: object

# %%
# Verificando se existe algum NaN ou inf
print(f'NaN:\n{memo_df.isna().any()}\n')
print(f'Inf:\n{np.isinf(memo_df.any())}\n')
# Out:
# NaN:
# Posição       False
# Endereço      False
# Área          False
# Quartos       False
# Banheiros     False
# Vagas         False
# Condomínio    False
# IPTU          False
# Descrição     False
# Status        False
# Página        False
# Preço          True
# dtype: bool
#
# Inf:
# Posição       False
# Endereço      False
# Área          False
# Quartos       False
# Banheiros     False
# Vagas         False
# Condomínio    False
# IPTU          False
# Descrição     False
# Status        False
# Página        False
# Preço         False
# dtype: bool

# %%
memo_df = memo_df.dropna()
memo_df['Preço'] = memo_df['Preço'].astype(int);
memo_df = memo_df.reset_index(drop=True)
# Out:
# <ipython-input-56-c6d139f66e6b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   memo_df['Preço'] = memo_df['Preço'].astype(int);

# %%
memo_df
# Out:
#        Posição                                           Endereço  Área  \
# 0            1                 Rodovia BR-364, Portal da Amazonia   420
# 1            2                 Rodovia BR-364, Portal da Amazonia   429
# 2            3  Rua Severina Maria de Sousa e Silva, Jardim Ma...    99
# 3            4                      Estrada do Calafate, Calafate    50
# 4            5                           Rua C, LBA Vila Betel ll   336
# ...        ...                                                ...   ...
# 19836       20                          Rua Chocalho, Castanheira   250
# 19837       21                        Rua Soledade, Marcos Freire    90
# 19838       22                 Rua Getúlio Vargas, São João Bosco   250
# 19839       23                              Rua Jamary, Pedrinhas   120
# 19840       24                             Rua Barbados, Embratel   100
#
#        Quartos  Banheiros  Vagas  Condomínio  IPTU  \
# 0            1          1      0           0     0
# 1            0          0      0           0     0
# 2            3          2      2         690     0
# 3            2          1      1           0     0
# 4            2          2      1           0     0
# ...        ...        ...    ...         ...   ...
# 19836        4          3      2           0     0
# 19837        2          1      0           0     0
# 19838        4          4      4           0     0
# 19839        3          4      2           0     0
# 19840        3          3      2         550     0
#
#                                                Descrição          Status  \
# 0      ECOVILLE Lindo lote venda plano sol manhã quad...  Super destaque
# 1      O lote terreno localizado bairro Portal Amazôn...  Super destaque
# 2      O apartamento localizado bairro Jardim Manoel ...  Super destaque
# 3      Vendo imóvel condomínio fechado Apartamento 2 ...           Comum
# 4      Casa Vila Betel Vende casa conj Vila Betel A c...           Comum
# ...                                                  ...             ...
# 19836  VENDE SE CASA NO BAIRRO CASTANHEIRAS Casa poss...        Destaque
# 19837  Grande oportunidade investidor Vila cinco apar...           Comum
# 19838  Vendo excelente residencia cidade Porto Velho ...        Destaque
# 19839  A casa localizado bairro Pedrinhas 120 metros ...           Comum
# 19840  Vende apartamento Apartamento 100m2 localizaçã...        Destaque
#
#        Página   Preço
# 0           1  389000
# 1           1  360000
# 2           1  570000
# 3           1   89000
# 4           1  185000
# ...       ...     ...
# 19836       1  160000
# 19837       1  135000
# 19838       1  450000
# 19839       1  550000
# 19840       1  580000
#
# [19841 rows x 12 columns]

# %% [markdown]
# ___
# ### 2.2 Lidando com a falta de dados
# Será usado o SimpleImputer da seguinte forma:
# ```python
# SimpleImputer(strategy='median')```

# %%
top5 = lambda column: memo_df[column].value_counts().index.sort_values().tolist()[-5:]
low5 = lambda column: memo_df[column].value_counts().index.sort_values().tolist()[:5]
low_and_top5 = lambda column: low5(column) + top5(column)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=0, strategy='median')
imputer.fit(memo_df.iloc[:, [0, 2, 3, 4, 5, 6, 7, 10, 11]])
memo_df.iloc[:, [0, 2, 3, 4, 5, 6, 7, 10, 11]] = imputer.transform(memo_df.iloc[:, [0, 2, 3, 4, 5, 6, 7, 10, 11]])
memo_df
# Out:
#        Posição                                           Endereço   Área  \
# 0          1.0                 Rodovia BR-364, Portal da Amazonia  420.0
# 1          2.0                 Rodovia BR-364, Portal da Amazonia  429.0
# 2          3.0  Rua Severina Maria de Sousa e Silva, Jardim Ma...   99.0
# 3          4.0                      Estrada do Calafate, Calafate   50.0
# 4          5.0                           Rua C, LBA Vila Betel ll  336.0
# ...        ...                                                ...    ...
# 19836     20.0                          Rua Chocalho, Castanheira  250.0
# 19837     21.0                        Rua Soledade, Marcos Freire   90.0
# 19838     22.0                 Rua Getúlio Vargas, São João Bosco  250.0
# 19839     23.0                              Rua Jamary, Pedrinhas  120.0
# 19840     24.0                             Rua Barbados, Embratel  100.0
#
#        Quartos  Banheiros  Vagas  Condomínio   IPTU  \
# 0          1.0        1.0    2.0       440.0  520.0
# 1          3.0        2.0    2.0       440.0  520.0
# 2          3.0        2.0    2.0       690.0  520.0
# 3          2.0        1.0    1.0       440.0  520.0
# 4          2.0        2.0    1.0       440.0  520.0
# ...        ...        ...    ...         ...    ...
# 19836      4.0        3.0    2.0       440.0  520.0
# 19837      2.0        1.0    2.0       440.0  520.0
# 19838      4.0        4.0    4.0       440.0  520.0
# 19839      3.0        4.0    2.0       440.0  520.0
# 19840      3.0        3.0    2.0       550.0  520.0
#
#                                                Descrição          Status  \
# 0      ECOVILLE Lindo lote venda plano sol manhã quad...  Super destaque
# 1      O lote terreno localizado bairro Portal Amazôn...  Super destaque
# 2      O apartamento localizado bairro Jardim Manoel ...  Super destaque
# 3      Vendo imóvel condomínio fechado Apartamento 2 ...           Comum
# 4      Casa Vila Betel Vende casa conj Vila Betel A c...           Comum
# ...                                                  ...             ...
# 19836  VENDE SE CASA NO BAIRRO CASTANHEIRAS Casa poss...        Destaque
# 19837  Grande oportunidade investidor Vila cinco apar...           Comum
# 19838  Vendo excelente residencia cidade Porto Velho ...        Destaque
# 19839  A casa localizado bairro Pedrinhas 120 metros ...           Comum
# 19840  Vende apartamento Apartamento 100m2 localizaçã...        Destaque
#
#        Página     Preço
# 0         1.0  389000.0
# 1         1.0  360000.0
# 2         1.0  570000.0
# 3         1.0   89000.0
# 4         1.0  185000.0
# ...       ...       ...
# 19836     1.0  160000.0
# 19837     1.0  135000.0
# 19838     1.0  450000.0
# 19839     1.0  550000.0
# 19840     1.0  580000.0
#
# [19841 rows x 12 columns]

# %%
memo_df['Preço'].describe()
# Out:
# count    1.984100e+04
# mean     6.996912e+05
# std      9.752877e+06
# min      1.000000e+03
# 25%      2.000000e+05
# 50%      3.100000e+05
# 75%      5.490000e+05
# max      7.300000e+08
# Name: Preço, dtype: float64

# %% [markdown]
# ___
# ### 2.3 Criando classificação de preço em ranges
#
# Será seguida a seguinte lógica, com base nos ranges dados por
#
# ```python
# memo_df['Preço'].mean() - memo_df['Preço'].median() # Menor que isso é barato
# # Entre os dois é considerado médio
# memo_df['Preço'].mean() + memo_df['Preço'].median() # Maior que isso é caro
# ```

# %%
mean = memo_df['Preço'].mean()
bands = memo_df['Preço'].median()
print(mean, bands)
# Out:
# 699691.1674310771 310000.0

# %%
memo_df['Range'] = np.where(
    memo_df['Preço'] < mean - bands, 'Barato',
    np.where(memo_df['Preço'] <= mean + bands, 'Médio', 'Caro'))
memo_df
# Out:
#        Posição                                           Endereço   Área  \
# 0          1.0                 Rodovia BR-364, Portal da Amazonia  420.0
# 1          2.0                 Rodovia BR-364, Portal da Amazonia  429.0
# 2          3.0  Rua Severina Maria de Sousa e Silva, Jardim Ma...   99.0
# 3          4.0                      Estrada do Calafate, Calafate   50.0
# 4          5.0                           Rua C, LBA Vila Betel ll  336.0
# ...        ...                                                ...    ...
# 19836     20.0                          Rua Chocalho, Castanheira  250.0
# 19837     21.0                        Rua Soledade, Marcos Freire   90.0
# 19838     22.0                 Rua Getúlio Vargas, São João Bosco  250.0
# 19839     23.0                              Rua Jamary, Pedrinhas  120.0
# 19840     24.0                             Rua Barbados, Embratel  100.0
#
#        Quartos  Banheiros  Vagas  Condomínio   IPTU  \
# 0          1.0        1.0    2.0       440.0  520.0
# 1          3.0        2.0    2.0       440.0  520.0
# 2          3.0        2.0    2.0       690.0  520.0
# 3          2.0        1.0    1.0       440.0  520.0
# 4          2.0        2.0    1.0       440.0  520.0
# ...        ...        ...    ...         ...    ...
# 19836      4.0        3.0    2.0       440.0  520.0
# 19837      2.0        1.0    2.0       440.0  520.0
# 19838      4.0        4.0    4.0       440.0  520.0
# 19839      3.0        4.0    2.0       440.0  520.0
# 19840      3.0        3.0    2.0       550.0  520.0
#
#                                                Descrição          Status  \
# 0      ECOVILLE Lindo lote venda plano sol manhã quad...  Super destaque
# 1      O lote terreno localizado bairro Portal Amazôn...  Super destaque
# 2      O apartamento localizado bairro Jardim Manoel ...  Super destaque
# 3      Vendo imóvel condomínio fechado Apartamento 2 ...           Comum
# 4      Casa Vila Betel Vende casa conj Vila Betel A c...           Comum
# ...                                                  ...             ...
# 19836  VENDE SE CASA NO BAIRRO CASTANHEIRAS Casa poss...        Destaque
# 19837  Grande oportunidade investidor Vila cinco apar...           Comum
# 19838  Vendo excelente residencia cidade Porto Velho ...        Destaque
# 19839  A casa localizado bairro Pedrinhas 120 metros ...           Comum
# 19840  Vende apartamento Apartamento 100m2 localizaçã...        Destaque
#
#        Página     Preço   Range
# 0         1.0  389000.0  Barato
# 1         1.0  360000.0  Barato
# 2         1.0  570000.0   Médio
# 3         1.0   89000.0  Barato
# 4         1.0  185000.0  Barato
# ...       ...       ...     ...
# 19836     1.0  160000.0  Barato
# 19837     1.0  135000.0  Barato
# 19838     1.0  450000.0   Médio
# 19839     1.0  550000.0   Médio
# 19840     1.0  580000.0   Médio
#
# [19841 rows x 13 columns]

# %%
memo_df['Range'].value_counts()
# Out:
# Barato    12799
# Médio      5241
# Caro       1801
# Name: Range, dtype: int64

# %% [markdown]
# ___
# ## 3 Classificação

# %% [markdown]
# ___
# ### 3.1 Separando dados em Treino e Teste

# %%
X_train, X_test, y_train, y_test = train_test_split(memo_df[['Endereço', 'Descrição', 'Status']],
                                                    memo_df['Range'],
                                                    test_size=0.25)

# %% [markdown]
# ___
# ### 3.2 Impacto da descrição no range

# %%
pipe = Pipeline([('vect', TfidfVectorizer(stop_words=stopwords.words('portuguese'))),
                 ('rf', RandomForestClassifier(n_estimators=100, n_jobs=-1))])

pipe.fit(X_train['Descrição'], y_train)
# Out:
# Pipeline(steps=[('vect',
#                  TfidfVectorizer(stop_words=['de', 'a', 'o', 'que', 'e', 'é',
#                                              'do', 'da', 'em', 'um', 'para',
#                                              'com', 'não', 'uma', 'os', 'no',
#                                              'se', 'na', 'por', 'mais', 'as',
#                                              'dos', 'como', 'mas', 'ao', 'ele',
#                                              'das', 'à', 'seu', 'sua', ...])),
#                 ('rf', RandomForestClassifier(n_jobs=-1))])

# %%
from sklearn.metrics import confusion_matrix
# Acertos no treino
y_pred = pipe.predict(X_train['Descrição'])
# Matriz de confusão
confusion_matrix(y_train, y_pred)
# Out:
# array([[9657,    5,   13],
#        [   1, 1298,   14],
#        [  21,    2, 3869]], dtype=int64)

# %%
accuracy_score(y_true=y_train, y_pred=y_pred)
# Out:
# 0.9962365591397849

# %%
# Acertos no teste
y_pred = pipe.predict(X_test['Descrição'])
# Matriz de confusão
confusion_matrix(y_test, y_pred)
# Out:
# array([[3055,    2,   67],
#        [ 124,  259,  105],
#        [ 410,   22,  917]], dtype=int64)

# %%
accuracy_score(y_true=y_test, y_pred=y_pred)
# Out:
# 0.8528522475307397

# %% [markdown]
# ___
# ### 3.3 Impacto do endereço no range

# %%
pipe = Pipeline([('vect', TfidfVectorizer(stop_words=stopwords.words('portuguese'))),
                 ('rf', RandomForestClassifier(n_estimators=100, n_jobs=-1))])

pipe.fit(X_train['Endereço'], y_train)
# Out:
# Pipeline(steps=[('vect',
#                  TfidfVectorizer(stop_words=['de', 'a', 'o', 'que', 'e', 'é',
#                                              'do', 'da', 'em', 'um', 'para',
#                                              'com', 'não', 'uma', 'os', 'no',
#                                              'se', 'na', 'por', 'mais', 'as',
#                                              'dos', 'como', 'mas', 'ao', 'ele',
#                                              'das', 'à', 'seu', 'sua', ...])),
#                 ('rf', RandomForestClassifier(n_jobs=-1))])

# %%
# Acertos no treino
y_pred = pipe.predict(X_train['Endereço'])
# Matriz de confusão
confusion_matrix(y_train, y_pred)
# Out:
# array([[9256,   65,  354],
#        [ 309,  791,  213],
#        [ 688,   99, 3105]], dtype=int64)

# %%
accuracy_score(y_true=y_train, y_pred=y_pred)
# Out:
# 0.8838709677419355

# %%
# Acertos no teste
y_pred = pipe.predict(X_test['Endereço'])
# Matriz de confusão
confusion_matrix(y_test, y_pred)
# Out:
# array([[2900,   31,  193],
#        [ 226,  175,   87],
#        [ 532,   50,  767]], dtype=int64)

# %%
accuracy_score(y_true=y_test, y_pred=y_pred)
# Out:
# 0.7744406369683532

# %% [markdown]
# ___
# ### 3.4 Impacto do status no range

# %%
pipe = Pipeline([('vect', TfidfVectorizer(stop_words=stopwords.words('portuguese'))),
                 ('rf', RandomForestClassifier(n_estimators=100, n_jobs=-1))])

pipe.fit(X_train['Status'], y_train)
# Out:
# Pipeline(steps=[('vect',
#                  TfidfVectorizer(stop_words=['de', 'a', 'o', 'que', 'e', 'é',
#                                              'do', 'da', 'em', 'um', 'para',
#                                              'com', 'não', 'uma', 'os', 'no',
#                                              'se', 'na', 'por', 'mais', 'as',
#                                              'dos', 'como', 'mas', 'ao', 'ele',
#                                              'das', 'à', 'seu', 'sua', ...])),
#                 ('rf', RandomForestClassifier(n_jobs=-1))])

# %%
# Acertos no treino
y_pred = pipe.predict(X_train['Status'])
# Matriz de confusão
confusion_matrix(y_train, y_pred)
# Out:
# array([[9329,    0,  346],
#        [ 935,    0,  378],
#        [3467,    0,  425]], dtype=int64)

# %%
accuracy_score(y_true=y_train, y_pred=y_pred)
# Out:
# 0.655510752688172

# %%
# Acertos no teste
y_pred = pipe.predict(X_test['Status'])
# Matriz de confusão
confusion_matrix(y_test, y_pred)
# Out:
# array([[3006,    0,  118],
#        [ 359,    0,  129],
#        [1214,    0,  135]], dtype=int64)

# %%
accuracy_score(y_true=y_test, y_pred=y_pred)
# Out:
# 0.6331384801451321

# %% [markdown]
# ___
# ## 4 Regressão

# %% [markdown]
# ___
# ### 4.1 Impacto de todas as outras variáveis no range

# %%
X_train, X_test, y_train, y_test = train_test_split(
    memo_df[['Posição', 'Área', 'Quartos', 'Banheiros', 'Vagas', 'Condomínio', 'IPTU', 'Página']],
    memo_df['Preço'],
    test_size=0.25)

# %%
pipe = Pipeline([('scaler', StandardScaler()),
                 ('rf', RandomForestRegressor(n_estimators=1000, n_jobs=-1, bootstrap=False))])

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('rf',
#                  RandomForestRegressor(bootstrap=False, n_estimators=1000,
#                                        n_jobs=-1))])

# %%
# Acertos no treino
y_pred = pipe.predict(X_train)

# %%
r2_score(y_train, y_pred)
# Out:
# 0.942574321510539

# %%
# Acertos no teste
y_pred = pipe.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# -0.23830145864923513
