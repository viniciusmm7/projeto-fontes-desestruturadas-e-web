# %%
# !pip install unidecode

# %%
# !conda install --yes -c conda-forge unidecode

# %%
import re, os, sys, requests, time, random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import bs4
from bs4 import BeautifulSoup
from unidecode import unidecode
from random import randint

# %%
print(f'O notebook está na pasta: {os.getcwd()}')
# Out:
# O notebook está na pasta: C:\Users\viniz\OneDrive\Área de Trabalho\Vinícius\Insper\Matérias\Eletivas\Análise de Texto e Fontes Desestruturadas e Web\Projeto\projeto-fontes-desestruturadas-e-web

# %%
url_capitais = 'https://www.todamateria.com.br/capitais-do-brasil/'

# %%
uf_capital = {} # Exemplo: {'SP': 'São Paulo', 'RJ', 'Rio de Janeiro'}
resposta = requests.get(url_capitais)
resposta.encoding = 'utf-8'

# %%
soup = BeautifulSoup(resposta.text, 'html.parser')

# %%
tabela = soup.find('tbody')
linhas = tabela.find_all('tr')
for linha in linhas:
    uf = linha.find_all('td')[2].text
    uf = uf.lower()
    capital = linha.find_all('td')[0].text
    capital = capital.lower()
    capital = capital.split()
    capital = '-'.join(capital)
    capital = unidecode(capital)
    uf_capital[uf] = capital
print(uf_capital)
# Out:
# {'ac': 'rio-branco', 'al': 'maceio', 'ap': 'macapa', 'am': 'manaus', 'ba': 'salvador', 'ce': 'fortaleza', 'df': 'brasilia', 'es': 'vitoria', 'go': 'goiania', 'ma': 'sao-luis', 'mt': 'cuiaba', 'ms': 'campo-grande', 'mg': 'belo-horizonte', 'pa': 'belem', 'pb': 'joao-pessoa', 'pr': 'curitiba', 'pe': 'recife', 'pi': 'teresina', 'rj': 'rio-de-janeiro', 'rn': 'natal', 'rs': 'porto-alegre', 'ro': 'porto-velho', 'rr': 'boa-vista', 'sc': 'florianopolis', 'sp': 'sao-paulo', 'se': 'aracaju', 'to': 'palmas'}

# %%
urls = []
for uf, capital in uf_capital.items():
    url = 'https://www.zapimoveis.com.br'
    uri = '/venda/imoveis/'
    uri += f'{uf}+{capital}'
    url += uri
    urls.append(url)
urls
# Out:
# ['https://www.zapimoveis.com.br/venda/imoveis/ac+rio-branco',
#  'https://www.zapimoveis.com.br/venda/imoveis/al+maceio',
#  'https://www.zapimoveis.com.br/venda/imoveis/ap+macapa',
#  'https://www.zapimoveis.com.br/venda/imoveis/am+manaus',
#  'https://www.zapimoveis.com.br/venda/imoveis/ba+salvador',
#  'https://www.zapimoveis.com.br/venda/imoveis/ce+fortaleza',
#  'https://www.zapimoveis.com.br/venda/imoveis/df+brasilia',
#  'https://www.zapimoveis.com.br/venda/imoveis/es+vitoria',
#  'https://www.zapimoveis.com.br/venda/imoveis/go+goiania',
#  'https://www.zapimoveis.com.br/venda/imoveis/ma+sao-luis',
#  'https://www.zapimoveis.com.br/venda/imoveis/mt+cuiaba',
#  'https://www.zapimoveis.com.br/venda/imoveis/ms+campo-grande',
#  'https://www.zapimoveis.com.br/venda/imoveis/mg+belo-horizonte',
#  'https://www.zapimoveis.com.br/venda/imoveis/pa+belem',
#  'https://www.zapimoveis.com.br/venda/imoveis/pb+joao-pessoa',
#  'https://www.zapimoveis.com.br/venda/imoveis/pr+curitiba',
#  'https://www.zapimoveis.com.br/venda/imoveis/pe+recife',
#  'https://www.zapimoveis.com.br/venda/imoveis/pi+teresina',
#  'https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro',
#  'https://www.zapimoveis.com.br/venda/imoveis/rn+natal',
#  'https://www.zapimoveis.com.br/venda/imoveis/rs+porto-alegre',
#  'https://www.zapimoveis.com.br/venda/imoveis/ro+porto-velho',
#  'https://www.zapimoveis.com.br/venda/imoveis/rr+boa-vista',
#  'https://www.zapimoveis.com.br/venda/imoveis/sc+florianopolis',
#  'https://www.zapimoveis.com.br/venda/imoveis/sp+sao-paulo',
#  'https://www.zapimoveis.com.br/venda/imoveis/se+aracaju',
#  'https://www.zapimoveis.com.br/venda/imoveis/to+palmas']

# %%
# ===== APENAS PARA A PRIMEIRA PÁGINA DE CADA CAPITAL POR ENQUANTO =====
'''
ANOTAÇÕES

- Fazer com que o código pesquise no Google o endereço de cada local e
retorne separadamente bairro, número, tipo de logradouro e
nome do logradouro;
OU
- Fazer com que o código pesquise no Google o endereço de cada local e
retorne a latitude e longitude, plotando num mapa ao decorrer do projeto;

- Fazer o Web Crawling de todas as páginas disponíveis para cada cidade
(é esperado que demore, pois cidades como São Paulo possuem milhões de
imóveis listados, talvez seja necessário considerar um limite máximo
como 10 mil imóveis por cidade);

- Não fazer a pesquisa com base nas ordenações disponíveis;

- Fazer com que o código acesse imóvel por imóvel e retone informações
booleanas adicionais do imóvel, por exemplo, se possui elevador (quantidade?),
se possui piscina (quantidade?), se possui academia, se possui espaços
para festas gerais;
''';

# %%
posicoes = []
enderecos = []
areas = []
quartos = []
banheiros = []
vagas = []
precos = []
conds = []
iptus = []
descricoes = []
lista_status = []
paginas = []

for url in urls:
    posicao = 1
    pagina = 1
    
    n1, n2, n3 = randint(0, 36), randint(0, 142), randint(0, 35)
    headers = {'user-agent':
               f'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.{n1} (KHTML, like Gecko) Chrome/75.0.3770.{n2} Safari/537.{n3}'
    }
    resposta = requests.get(url, headers=headers)
    resposta.encoding = 'utf-8'
    
    soup = BeautifulSoup(resposta.text, 'html.parser')
    
    lista_prod = soup.find('div', class_='listings__container')
    produtos = lista_prod.find_all('div', class_='card-container js-listing-card')
    for produto in produtos:
        
        # ----- Posição na página
        posicoes.append(posicao)
        posicao += 1
        
        # Endereço
        try:
            endereco = produto.find('h2', attrs={'itemprop': 'address'}).text
            endereco = endereco.strip('\n ')
            enderecos.append(endereco)
        except:
            enderecos.append(None)
        
        # ----- Área
        try:
            area = produto.find('li', class_='feature__item text-small js-areas').text
            area = area.strip('\n ')
            area = area.replace('m²', '')
            areas.append(area)
        except:
            areas.append(None)
        
        # ----- Qtd quartos
        try:
            quarto = produto.find('span', attrs={'itemprop': 'numberOfRooms'}).text
            quarto = quarto.strip('\n ') # Pode ser algo do tipo: '1 - 3'
            quartos.append(quarto)
        except:
            quartos.append(None)
        
        # ----- Qtd banheiros
        try:
            banheiro = produto.find('span', attrs={'itemprop': 'numberOfBathroomsTotal'}).text
            banheiro = banheiro.strip('\n ') # Pode ser algo do tipo: '1 - 3'
            banheiros.append(banheiro)
        except:
            banheiros.append(None)
        
        # ----- Qtd vagas
        try:
            vaga = produto.find('li', class_='feature__item text-small js-parking-spaces').text
            vaga = vaga.strip('\n ') # Pode ser algo do tipo: '1 - 3'
            vagas.append(vaga)
        except:
            vagas.append(None)
        
        # ----- Preço condomínio
        try:
            cond = produto.find('li', class_='card-price__item condominium text-regular').text
            conds.append(''.join(re.findall(r'\d+', cond)))
        except:
            conds.append(None)
            
        # ----- IPTU
        try:
            iptu = produto.find('li', class_='card-price__item iptu text-regular').text
            iptus.append(''.join(re.findall(r'\d+', iptu)))
        except:
            iptus.append(None)
        
        # ----- Decrição
        try:
            descricao = produto.find('span', attrs={'itemprop': 'description'}).text
            descricoes.append(descricao)
        except:
            descricoes.append(None)
        
        # ----- Status
        try:
            status = produto.find('small').text
        except:
            status = 'Comum'
        lista_status.append(status)
        
        # ----- Número da página
        paginas.append(pagina)
        
        # ----- Preço
        preco = produto.find('p', class_='simple-card__price js-price color-darker heading-regular heading-regular__bolder align-left').text
        precos.append(''.join(re.findall(r'\d+', preco)))
        
    pagina += 1

# %%
dicionario = {'Posição': posicoes,
              'Endereço': enderecos,
              'Área': areas,
              'Quartos': quartos,
              'Banheiros': banheiros,
              'Vagas': vagas,
              'Condomínio': conds,
              'IPTU': iptus,
              'Descrição': descricoes,
              'Status': lista_status,
              'Página': paginas,
              'Preço': precos}

# %%
df = pd.DataFrame(dicionario)
df.head()
# Out:
#    Posição                                       Endereço  Área Quartos  \
# 0        1  Avenida Recanto Verde, Residencial Petropolis  114        3
# 1        2               Rua Belo Horizonte, Ivete Vargas  170        4
# 2        3                      Rua Acre, Vila da Amizade   50        2
# 3        4                 Avenida Getúlio Vargas, Centro  250        3
# 4        5                       Rua C, LBA Vila Betel ll  336        2
#
#   Banheiros Vagas Condomínio  IPTU  \
# 0         2     2       None  None
# 1         2     1       None  None
# 2         1     1       None  None
# 3      None     2       None  None
# 4         2     1       None  None
#
#                                            Descrição    Status  Página   Preço
# 0  O sobrado no bairro Primavera possui 114 metro...  Destaque       1  495000
# 1  Vende-se uma casa no Ivete Vargas. A casa poss...  Destaque       1  245000
# 2  Aluga-se apartamento no Residencial Villacre, ...     Comum       1  150000
# 3                                               None  Destaque       1  500000
# 4  ?Casa na Vila Betel !  Vende-se uma casa no co...  Destaque       1  185000

# %%
cwd = str(os.getcwd())
_, _, files = next(os.walk(cwd))
file_count = len(files)
print(file_count)

df.to_csv(f'data{file_count - 1}.csv')
# Out:
# 7

# %%
# Tipos de status
df['Status'].value_counts().index
# Out:
# Index(['Destaque', 'Comum', 'Super destaque', 'Em construção', 'Na planta',
#        'Pronto para morar'],
#       dtype='object')

# %%
# Quantidade bruta de imóveis por tipo de status
df['Status'].value_counts()
# Out:
# Destaque             257
# Comum                246
# Super destaque        76
# Em construção         30
# Na planta             23
# Pronto para morar     16
# Name: Status, dtype: int64

# %%
# Quantidade relativa de imóveis por tipo de status
df['Status'].value_counts(True).round(4)*100
# Out:
# Destaque             39.66
# Comum                37.96
# Super destaque       11.73
# Em construção         4.63
# Na planta             3.55
# Pronto para morar     2.47
# Name: Status, dtype: float64

# %%
super_mask = df['Status'] == 'Super destaque'
super_df = df.loc[super_mask, :]
super_df
# Out:
#      Posição                                           Endereço  Área Quartos  \
# 27         4  Avenida General Luiz de França Albuquerque, Ja...  141        4
# 28         5       Rua Doutor José Corrêa Filho, Ponta da Terra   71        3
# 29         6    Avenida Engenheiro Mário de Gusmão, Ponta Verde   31     None
# 48         1            Alameda das Estrelas, Muruci Fazendinha  332     None
# 75         4                   Avenida Ephigênio Salles, Aleixo  494        3
# ..       ...                                                ...   ...     ...
# 604        5                      Rua Matilde Silva Lima, Luzia   68        3
# 605        6                                Rua Alecrim, Robalo  250     None
# 627        4                          Plano Diretor Sul, Palmas  368     None
# 628        5      ARSO 43 Alameda Circular 1, Plano Diretor Sul  178        3
# 629        6               ARSO 43 Alameda 9, Plano Diretor Sul  480     None
#
#     Banheiros Vagas Condomínio  IPTU  \
# 27          5     3        840  None
# 28          2     1       None  None
# 29          1  None       None  None
# 48       None  None        350  None
# 75          5     4       1300  3429
# ..        ...   ...        ...   ...
# 604         1     1        302  None
# 605      None  None       None  None
# 627      None  None       None  None
# 628         3     2       None  None
# 629      None  None       None  None
#
#                                              Descrição          Status  \
# 27   Um novo conceito em empreendimento imobiliário...  Super destaque
# 28   Excelente apartamento com três quartos complet...  Super destaque
# 29   O centro comercial está localizado no bairro P...  Super destaque
# 48   Lotes medindo mais de 332,00m²  em excelente l...  Super destaque
# 75   Casa disponível para locação ou venda no condo...  Super destaque
# ..                                                 ...             ...
# 604  Apartamento térreo amplo com sala, hall, três ...  Super destaque
# 605  Depois do grande sucesso de vendas do Villared...  Super destaque
# 627  Prédio Comercial a venda  Localização mais que...  Super destaque
# 628  Casa na 407 Sul  3/4 sendo 2 suites  banheiro ...  Super destaque
# 629  Maiores informações ou querendo agendar uma vi...  Super destaque
#
#      Página    Preço
# 27        1  1300000
# 28        1   350000
# 29        1   280000
# 48        1   250000
# 75        1  3700000
# ..      ...      ...
# 604       1   155000
# 605       1     1000
# 627       1  3300000
# 628       1   830000
# 629       1   270000
#
# [76 rows x 12 columns]

# %%
destaque_mask = df['Status'] == 'Destaque'
destaque_df = df.loc[destaque_mask, :]
destaque_df
# Out:
#      Posição                                           Endereço  Área Quartos  \
# 0          1      Avenida Recanto Verde, Residencial Petropolis  114        3
# 1          2                   Rua Belo Horizonte, Ivete Vargas  170        4
# 3          4                     Avenida Getúlio Vargas, Centro  250        3
# 4          5                           Rua C, LBA Vila Betel ll  336        2
# 5          6                 Rua Porto Velho, Loteamento Joafra  250        2
# ..       ...                                                ...   ...     ...
# 642       19  Loteamento Residencial Polinésia, Loteamento R...  832     None
# 643       20                          Plano Diretor Sul, Palmas  140        3
# 644       21                          Plano Diretor Sul, Palmas  130        3
# 645       22                                 Rua 17, Taquarussu  300        4
# 647       24                        Plano Diretor Norte, Palmas   68        3
#
#     Banheiros Vagas Condomínio  IPTU  \
# 0           2     2       None  None
# 1           2     1       None  None
# 3        None     2       None  None
# 4           2     1       None  None
# 5           2     2       None  None
# ..        ...   ...        ...   ...
# 642      None  None       None  None
# 643         3     3       None  None
# 644         3  None       None  None
# 645         4     6       None  None
# 647         2     2       None  None
#
#                                              Descrição    Status  Página  \
# 0    O sobrado no bairro Primavera possui 114 metro...  Destaque       1
# 1    Vende-se uma casa no Ivete Vargas. A casa poss...  Destaque       1
# 3                                                 None  Destaque       1
# 4    ?Casa na Vila Betel !  Vende-se uma casa no co...  Destaque       1
# 5    VEND0 casa localizada no loteamento Joafra, pr...  Destaque       1
# ..                                                 ...       ...     ...
# 642  Lote no condomínio Residencial Polinésia   Lot...  Destaque       1
# 643  Casa nova na quadra 309 Sul com 140m2 de área ...  Destaque       1
# 644  Vendo sobrado novo localizado na quadra 505 SU...  Destaque       1
# 645  🧡 Linda chácara , às margens da PALMAS -TO a T...  Destaque       1
# 647  Vende-se apartamento de 3/4  Sendo 68 m² muito...  Destaque       1
#
#        Preço
# 0     495000
# 1     245000
# 3     500000
# 4     185000
# 5     270000
# ..       ...
# 642   430000
# 643   600000
# 644   480000
# 645  2200000
# 647   245000
#
# [257 rows x 12 columns]

# %%
comum_mask = df['Status'] == 'Comum'
comum_df = df.loc[comum_mask, :]
comum_df
# Out:
#      Posição                                           Endereço   Área  \
# 2          3                          Rua Acre, Vila da Amizade    50
# 7          8  Rua Severina Maria de Sousa e Silva, Jardim Ma...    99
# 13        14                     Rodovia BR-364, Belo Jardim II  5000
# 15        16                      Estrada do Calafate, Calafate    50
# 16        17                  Rua São Mateus, Residencial Araca    49
# ..       ...                                                ...    ...
# 631        8                          Plano Diretor Sul, Palmas   103
# 635       12                          Plano Diretor Sul, Palmas   113
# 639       16                        Plano Diretor Norte, Palmas    87
# 641       18                          Jardim Aureny III, Palmas   120
# 646       23                        Graciosa - Orla 14 , Palmas   105
#
#     Quartos Banheiros Vagas Condomínio  IPTU  \
# 2         2         1     1       None  None
# 7         3         2     2       None  None
# 13        3         2     2       None  None
# 15        2         1     1       None  None
# 16        2         1     1        230   300
# ..      ...       ...   ...        ...   ...
# 631       3         3     2       None  None
# 635       3         4     2       None  None
# 639       3         2     2       None  None
# 641       3         2     2       None  None
# 646       3         3     2       None  None
#
#                                              Descrição Status  Página   Preço
# 2    Aluga-se apartamento no Residencial Villacre, ...  Comum       1  150000
# 7    O apartamento no bairro Jardim Manoel Julião t...  Comum       1  500000
# 13   Chácara a venda no Polo Belo Jardim com 5000 m...  Comum       1  200000
# 15   Vendo esse imóvel em condomínio fechado. Apart...  Comum       1   89000
# 16   O apartamento no bairro Residencial Araçá com ...  Comum       1  185000
# ..                                                 ...    ...     ...     ...
# 631  1003 Sul; Lote: 180 m²  Área construída: 103 m...  Comum       1  385000
# 635  Área Privativa: 113m²  3 Suítes plenas Sala am...  Comum       1  670000
# 639  Vendo Ágio de apartamento novo Pronto para Mor...  Comum       1   80000
# 641  Vendo casa de esquina localizada no Aureny III...  Comum       1  190000
# 646  RESIDENCIAL PORTAL DA ORLA ORLA 14 - (PRAIA DA...  Comum       1  430000
#
# [246 rows x 12 columns]

# %%
construcao_mask = df['Status'] == 'Em construção'
construcao_df = df.loc[construcao_mask, :]
construcao_df
# Out:
#      Posição                                           Endereço        Área  \
# 26         3                       Rua Valdo Omena, Ponta Verde    37 - 79
# 98         3                          Rua Parambu, Santa Teresa         58
# 121        2                         Rua Gonçalves Ledo, Centro        100
# 122        3                         Rua Gonçalves Ledo, Centro        100
# 192        1                                Rua 22, Setor Oeste        219
# 193        2                                Rua 22, Setor Oeste        148
# 194        3                                Rua 22, Setor Oeste         88
# 240        1                            Avenida Ipiranga, Porto    35 - 44
# 241        2  Avenida Fernando Correa da Costa, Jardim Petró...        165
# 242        3              Avenida Oátomo Canavarros, Bela Vista    39 - 42
# 264        1                     Rua Franklin Roosevelt, Centro    41 - 91
# 265        2   Rua Petrópolis, Parque Residencial dos Girassóis    39 - 61
# 266        3   Avenida Senador Antonio Mendes Canale, Pioneiros    39 - 56
# 288        1                         Rua Espírito Santo, Centro    45 - 65
# 289        2                         Rua Espírito Santo, Centro    45 - 50
# 312        1        Avenida Conselheiro Furtado, Batista Campos        100
# 314        3             Travessa Dom Romualdo Coelho, Umarizal        300
# 336        1    Avenida Presidente Epitácio Pessoa, Tambauzinho   48 - 417
# 337        2                        Avenida Maria Rosa, Manaíra         57
# 360        1             Avenida Visconde de Guarapuava, Centro    20 - 36
# 384        1                Rua Doutor Leopoldo Lins, Boa Vista         60
# 385        2                       Rua Monte Castelo, Boa Vista    33 - 37
# 408        1                 Avenida Miguel Sady, São Cristóvão        142
# 457        2       Avenida Moema Tinoco da Cunha Lima, Pajuçara    41 - 44
# 480        1           Rua Coronel Paulino Teixeira, Rio Branco  143 - 219
# 552        1                    Rua Presidente Coutinho, Centro  101 - 119
# 554        3            Rua João Motta Espezim, Saco dos Limões   89 - 117
# 577        2                    Rua Francisca Miquelina, Centro    28 - 31
# 601        2   Avenida Doutor Carlos Rodrigues da Cruz, Capucho    40 - 45
# 625        2        Quadra ARSE 41 Alameda 2, Plano Diretor Sul        357
#
#     Quartos Banheiros  Vagas Condomínio  IPTU  \
# 26    1 - 2         1  1 - 2       None  None
# 98        2         2      1       None  None
# 121       3         4      2       None  None
# 122       3         4      3       None  None
# 192       4         6      4       None  None
# 193   3 - 4         5      3       None  None
# 194   2 - 3         3      2       None  None
# 240   1 - 2         1      1       None  None
# 241    None         5      3       None  None
# 242       2         1      1       None  None
# 264   1 - 2     1 - 2  1 - 2       None  None
# 265       2         1      1       None  None
# 266       2         1      1       None  None
# 288       2         1      1       None  None
# 289       2         1      1       None  None
# 312       3         3      2       None  None
# 314       4         5      4       None  None
# 336    None      None   None       None  None
# 337   2 - 3     1 - 2  1 - 2       None  None
# 360       1         1  0 - 1       None  None
# 384       3         2      2       None  None
# 385       1         1      1       None  None
# 408       3         5  3 - 4       None  None
# 457       2         1      1       None  None
# 480       3         5  2 - 3       None  None
# 552       3     2 - 3      2       None  None
# 554   2 - 3     3 - 4      2       None  None
# 577       1         1   None       None  None
# 601       2         1      1       None  None
# 625       3         4  3 - 4       None  None
#
#                                              Descrição         Status  Página  \
# 26                        Venha conhecer o Smart Stay.  Em construção       1
# 98   Residencial Santorini – BRF Realizações  Jardi...  Em construção       1
# 121  LAZER COMPLETO Piscina adulto e infantil com d...  Em construção       1
# 122  Venha morar onde o melhor da vida acontece!  R...  Em construção       1
# 192  Adagio - Opção de 3 suítes com possibilidade d...  Em construção       1
# 193  Moderato - Sala com mega esquadria e balcão qu...  Em construção       1
# 194  Allegro -Opção de transformar em 3 quartos; Me...  Em construção       1
# 240  Apartamentos de 2 quartos no Porto, em condomí...  Em construção       1
# 241  O Harissa é um empreendimento único em Cuiabá....  Em construção       1
# 242  Energia Solar Áreas Comuns, Elevador, Piso Lam...  Em construção       1
# 264  O Vista é um empreendimento único em Campo Gra...  Em construção       1
# 265  Piso Laminado na Sala, Piso Laminado no Quarto...  Em construção       1
# 266  Piso Laminado na Sala, Piso Laminado no Quarto...  Em construção       1
# 288  O Metropolis é um empreendimento exclusivo par...  Em construção       1
# 289  Metropolis, aonde você realmente merece morar....  Em construção       1
# 312  W BATISTA CAMPOS É COMPLETÍSSIMO. Tem até um e...  Em construção       1
# 314  Venha conhecer os diferenciais incríveis desse...  Em construção       1
# 336  ATLANTIS OFFICES  Seu sucesso. Seu lugar.  A E...  Em construção       1
# 337  Com um inovador projeto, baseado em sugestões ...  Em construção       1
# 360  More ou invista na região que mais valoriza em...  Em construção       1
# 384  UM SONHO DE LOCALIZAÇÃO! 60m², 03 quartos, 01 ...  Em construção       1
# 385  Antecipe-se ao Lançamento, FLAT, mais rentabil...  Em construção       1
# 408  Reserva Vilmary - Uma Reserva Especial para vo...  Em construção       1
# 457  Piso Laminado no Quarto, Piso Laminado na Sala...  Em construção       1
# 480  Arte, design e arquitetura. Apartamentos de 3 ...  Em construção       1
# 552  O ENDEREÇO CERTO PARA VOCÊ VIVER BEM.  Apartam...  Em construção       1
# 554  RESIDENCIAL ESTORIL - Cobertura Duplex de 02 Q...  Em construção       1
# 577  Ultimas unidades  O Esquina Paulicéia foi proj...  Em construção       1
# 601  Praia de Atalaia. Transforme a vida da sua fam...  Em construção       1
# 625  Venha conhecer os diferenciais incríveis desse...  Em construção       1
#
#        Preço
# 26
# 98    395000
# 121
# 122   759000
# 192  1684727
# 193  1088094
# 194   651407
# 240   217990
# 241
# 242   171990
# 264   412000
# 265   173990
# 266   154690
# 288   480000
# 289   453000
# 312
# 314
# 336   460734
# 337   355000
# 360   161000
# 384   395412
# 385   280000
# 408
# 457   151490
# 480  2172381
# 552
# 554   800000
# 577   365000
# 601   146690
# 625

# %%
planta_mask = df['Status'] == 'Na planta'
planta_df = df.loc[planta_mask, :]
planta_df
# Out:
#      Posição                                         Endereço        Área  \
# 24         1    Avenida Comendador Gustavo Paiva, Mangabeiras    39 - 71
# 73         2                   Rua Fulvio Pennanchi, Planalto    38 - 43
# 97         2            Rua Doutor Genésio Salles, Vila Laura    61 - 89
# 120        1              Rua Nogueira Acioli, Joaquim Tavora    51 - 65
# 144        1                 SQNW 102 Bloco F, Setor Noroeste        263
# 145        2                 SQNW 302 Bloco H, Setor Noroeste        153
# 146        3                 SQNW 302 Bloco H, Setor Noroeste         71
# 168        1                         Rua das Marrecas, Centro    32 - 66
# 170        3                       Rua Irineu Marinho, Centro         35
# 216        1               Avenida Dom José Delgado, Alemanha    39 - 42
# 218        3            Avenida dos Holandeses, Ponta D'areia    81 - 90
# 338        3                          Avenida Pombal, Manaíra         41
# 361        2           Avenida Visconde de Guarapuava, Centro    32 - 72
# 386        3                         Rua Dom Bosco, Boa Vista    30 - 68
# 409        2  Rua Desembargador Manoel Castelo Branco, Jóquei  225 - 229
# 410        3                     Avenida Jóquei Clube, Jóquei  225 - 377
# 432        1                         Rua das Marrecas, Centro    32 - 66
# 434        3                       Rua Irineu Marinho, Centro         35
# 481        2                 Rua Professor Duplan, Rio Branco    25 - 66
# 553        2          Rua Desembargador Urbano Salles, Centro   73 - 117
# 576        1              Rua Francisca Miquelina, Bela Vista         48
# 602        3       Rua Antônio Teixeira Gonçalves, Farolândia    38 - 46
# 624        1         Orla 14 Avenida Orla, Graciosa - Orla 14   91 - 120
#
#     Quartos Banheiros  Vagas Condomínio  IPTU  \
# 24     None         2   None       None  None
# 73    1 - 2         1      1       None  None
# 97    2 - 3     2 - 3  1 - 2       None  None
# 120   2 - 3     2 - 3  1 - 2       None  None
# 144       3         5      3       None  None
# 145       2         3      2       None  None
# 146       2         3      1       None  None
# 168       1         1   None       None  None
# 170   1 - 2         1   None       None  None
# 216       2         1      1       None  None
# 218       3         1      2       None  None
# 338   1 - 3     1 - 2  1 - 2       None  None
# 361   1 - 2     1 - 2  1 - 3       None  None
# 386   1 - 3     1 - 2  1 - 2       None  None
# 409       4         5      5       None  None
# 410       4         5  3 - 4       None  None
# 432       1         1   None       None  None
# 434   1 - 2         1   None       None  None
# 481   1 - 2     1 - 2      1       None  None
# 553   2 - 3     2 - 4  1 - 2       None  None
# 576       2         1   None       None  None
# 602   1 - 2         1      1       None  None
# 624       3     2 - 4  2 - 3       None  None
#
#                                              Descrição     Status  Página  \
# 24   THE ICON PARK OFFICE  Um EMPRESARIAL ao lado d...  Na planta       1
# 73   Lazer equipado, Previsão para medição de água ...  Na planta       1
# 97   O melhor da Vila Laura para você. Escolha mais...  Na planta       1
# 120  Modernidade, conforto e acessibilidade. Elemen...  Na planta       1
# 144  Cobertura Duplex de 3 Suítes Noroeste - Parque...  Na planta       1
# 145  Cobertura Duplex 2 quartos, com até 2 suítes N...  Na planta       1
# 146  Apartamento 2 quartos, com até 2 suítes Noroes...  Na planta       1
# 168  Hub Coliving. Studios com área de convivência ...  Na planta       1
# 170  Cores do Rio Centro da Cidade RJ: É o primeiro...  Na planta       1
# 216  Apartamentos de 2 quartos no Alemanha, em cond...  Na planta       1
# 218  Imagine alcançar outro nível na sua qualidade ...  Na planta       1
# 338  Localizado em Manaíra, a 300 metros do mar, o ...  Na planta       1
# 361  Conheça o Mont Tannat, o novo empreendimento d...  Na planta       1
# 386  BREVE LANÇAMENTO: Imagine estar no centro de t...  Na planta       1
# 409  APARTAMENTO COM 4 SUITES 3 CLOSET. ÁREA 2229,3...  Na planta       1
# 410  O seu apartamento de alto padrão no Jóquei, o ...  Na planta       1
# 432  Hub Coliving. Studios com área de convivência ...  Na planta       1
# 434  Cores do Rio Centro da Cidade RJ: É o primeiro...  Na planta       1
# 481  Um jeito inteligente e sob medida de viver e p...  Na planta       1
# 553                                               None  Na planta       1
# 576  2 Dorms. a partir de R$ 485 mil. 10 min. da Av...  Na planta       1
# 602  Forro de gesso no banheiro, Revestimento total...  Na planta       1
# 624  Acqua Design Palmas. O projeto que é a nova re...  Na planta       1
#
#        Preço
# 24    297394
# 73    176490
# 97    387480
# 120
# 144
# 145  2113929
# 146  1080181
# 168
# 170   272000
# 216   163990
# 218   889300
# 338   263000
# 361   258013
# 386
# 409  2458300
# 410  2162800
# 432
# 434   272000
# 481   313435
# 553  1043000
# 576   485000
# 602   189990
# 624   718672

# %%
pronto_mask = df['Status'] == 'Pronto para morar'
pronto_df = df.loc[pronto_mask, :]
pronto_df
# Out:
#      Posição                                       Endereço       Área  \
# 25         2                Rua Doutora Rosa Cabús, Jatiúca   40 - 59
# 72         1          Avenida Coronel Teixeira, Ponta Negra   66 - 88
# 74         3          Avenida Coronel Teixeira, Ponta Negra   36 - 49
# 96         1         3ª Travessa Paripiranga, Bairro da Paz   53 - 71
# 169        2                 Rua Ubaldino do Amaral, Centro   38 - 69
# 217        2                  Avenida da História, Cohafuma   28 - 38
# 290        3                Avenida Álvares Cabral, Lourdes   78 - 83
# 313        2                          Rua Timbiras, Jurunas        82
# 362        3      Avenida Marechal Floriano Peixoto, Centro        80
# 433        2                 Rua Ubaldino do Amaral, Centro   38 - 69
# 456        1               Rua Princesa Isabel, Cidade Alta        71
# 458        3            Rua José Pegado Mendes, Jardim Lola        54
# 482        3       Rua Doutor Lauro de Oliveira, Rio Branco        47
# 578        3               Rua Aguiar de Barros, Bela Vista   45 - 64
# 600        1  Avenida Doutor José Machado de Souza, Jardins  41 - 330
# 626        3   Quadra ARSE 21 Alameda 11, Plano Diretor Sul       166
#
#     Quartos Banheiros  Vagas Condomínio  IPTU  \
# 25    1 - 2     1 - 2      1       None  None
# 72    2 - 3     2 - 3      1       None  None
# 74    1 - 2         1      1       None  None
# 96    2 - 3         2      1       None  None
# 169   1 - 2     1 - 2      1       None  None
# 217       1         1      1       None  None
# 290       3         3  2 - 3       None  None
# 313       3         2      1       None  None
# 362    None      None   None       None  None
# 433   1 - 2     1 - 2      1       None  None
# 456       3         3      2       None  None
# 458       2      None      1       None  None
# 482       1         1      1       None  None
# 578   1 - 2         1      1       None  None
# 600    None         1      1       None  None
# 626       3         5      3       None  None
#
#                                              Descrição             Status  \
# 25   Viva o presente, invista no futuro!  Viver é g...  Pronto para morar
# 72   Pronto para morar ao lado do Shopping Ponta Ne...  Pronto para morar
# 74   A região da Ponta Negra é um dos pontos mais n...  Pronto para morar
# 96   Pronto para morar pertinho da praia!Pronto par...  Pronto para morar
# 169  A vida prática e moderna, como nas cidades mai...  Pronto para morar
# 217  residencial cohafuma: do tamanho certo para vo...  Pronto para morar
# 290  Lumière Residence Service, o reflexo dos seus ...  Pronto para morar
# 313  Venha conhecer os diferenciais incríveis desse...  Pronto para morar
# 362  Na esquina da Rua Marechal Floriano com Av. Se...  Pronto para morar
# 433  A vida prática e moderna, como nas cidades mai...  Pronto para morar
# 456  O melhor prédio da Cidade Alta, entre Tirol e ...  Pronto para morar
# 458  Cidade Arvoredo, bairro planejado em São Gonça...  Pronto para morar
# 482  Apartamentos modernos que irão inspirar o seu ...  Pronto para morar
# 578  Morar em um espaço modernos e contemporâneo, n...  Pronto para morar
# 600  Escritórios e Consultorios de 41,30m² até 300m...  Pronto para morar
# 626  Venha conhecer os diferenciais desse empreendi...  Pronto para morar
#
#      Página    Preço
# 25        1
# 72        1   340000
# 74        1
# 96        1
# 169       1   349900
# 217       1   145000
# 290       1  1149572
# 313       1
# 362       1   526316
# 433       1   349900
# 456       1   340000
# 458       1    79900
# 482       1   493832
# 578       1  1226340
# 600       1
# 626       1   997000

# %%
# Acessar os dados salvos e criar um novo DataFrame sem os duplicados
def get_data_files() -> list:
    data_files = []
    cwd = str(os.getcwd())
    _, _, files = next(os.walk(cwd))
    for file in files:
        if 'data' in file:
            data_files.append(file)
    return data_files

def standard_dict() -> dict:
    return {'Posição': [],
            'Endereço': [],
            'Área': [],
            'Quartos': [],
            'Banheiros': [],
            'Vagas': [],
            'Condomínio': [],
            'IPTU': [],
            'Descrição': [],
            'Status': [],
            'Página': [],
            'Preço': []}

def generate_data() -> pd.DataFrame:
    dicio_vazio = standard_dict()
    memo_df = pd.DataFrame(dicio_vazio)
    data_files = get_data_files()
    
    for data in data_files:
        d = pd.read_csv(data)
        memo_df = pd.concat([memo_df, d])
        
    memo_df = memo_df.iloc[:, :-1]
    memo_df = memo_df.reset_index()
    memo_df = memo_df.drop('index', axis=1)
    memo_df = memo_df.drop_duplicates()
    memo_df = memo_df.reset_index()
    return memo_df

# %%
memo_df = generate_data()
memo_df
# Out:
#       index  Posição                                           Endereço  Área  \
# 0         0      1.0                 Rodovia BR-364, Portal da Amazonia  420
# 1         1      2.0                 Rodovia BR-364, Portal da Amazonia  429
# 2         2      3.0  Rua Severina Maria de Sousa e Silva, Jardim Ma...   99
# 3         3      4.0                      Estrada do Calafate, Calafate   50
# 4         4      5.0                           Rua C, LBA Vila Betel ll  336
# ...     ...      ...                                                ...   ...
# 1827   3855     16.0                                    Aruana, Aracaju   60
# 1828   3856     17.0               Rua Antônio de Pádua Araújo, Grageru   85
# 1829   3857     18.0                           Rua São João, Industrial   60
# 1830   3858     19.0                        Rua François Hoald, Atalaia   93
# 1831   3863     24.0                        Avenida Poço do Mero, Bugio   65
#
#      Quartos Banheiros Vagas  Condomínio  IPTU  \
# 0          1         1   NaN         NaN   NaN
# 1        NaN       NaN   NaN         NaN   NaN
# 2          3         2     2       690.0   NaN
# 3          2         1     1         NaN   NaN
# 4          2         2     1         NaN   NaN
# ...      ...       ...   ...         ...   ...
# 1827       2         2     1         NaN   NaN
# 1828       3         2     1         NaN   NaN
# 1829       2         1     1       250.0   NaN
# 1830       2         3     2       790.0   NaN
# 1831       3         1     1         NaN   NaN
#
#                                               Descrição          Status  \
# 0     ECOVILLE- Lindo lote a venda, plano, sol da ma...  Super destaque
# 1     O lote/terreno está localizado no bairro Porta...  Super destaque
# 2     O apartamento está localizado no bairro Jardim...  Super destaque
# 3     Vendo esse imóvel em condomínio fechado. Apart...           Comum
# 4     ?Casa na Vila Betel !  Vende-se uma casa no co...           Comum
# ...                                                 ...             ...
# 1827  ARUANA PRAIA RESIDENCE              **Agende a...           Comum
# 1828  Vendo Apartamento no Condomínio Tropical Villa...           Comum
# 1829  Apartamento de 2/4 com:Sala;Wc social;Cozinha;...        Destaque
# 1830  - Oportunidade ! - Apartamento com 93m² no Con...           Comum
# 1831  Apto de 3/4 com Varanda  Andar Alto com Bela V...           Comum
#
#       Página     Preço
# 0        1.0  389000.0
# 1        1.0  360000.0
# 2        1.0  570000.0
# 3        1.0   89000.0
# 4        1.0  185000.0
# ...      ...       ...
# 1827     1.0  170938.0
# 1828     1.0  425000.0
# 1829     1.0  130000.0
# 1830     1.0  620000.0
# 1831     1.0  170074.0
#
# [1832 rows x 13 columns]

# %%
# Teste
for i in memo_df.duplicated():
    if i:
        print("Achou duplicado")
